# %%
# all imports, numpy, scipy, matplotlib, seaborn, pandas, plotly


import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import sklearn 
import os
from matplotlib import cm as colours 
from colorama import Fore, Back, Style
from scipy.stats import sem
import joblib
import pickle

# %%
# load the data for both mfa and normal annotations 
pkl_path = r"Pickle Files\patient_data.pkl"

if os.path.exists(pkl_path):
    with open(pkl_path, "rb") as f:
        patient_data = pickle.load(f)
    print("Loaded patient_data from pickle.")
else:
    path = r"C:\Users\Nabiya\Box\Academic-Duke\CoganLab\Summer 2024\intraop\ieeg_data_intraop\Zac_intraop_data"
    patients = ['S14', 'S22', 'S23', 'S26', 'S33']
    positions = ['p1', 'p2', 'p3']

    patient_data = {}

    for patient in patients:
        patient_data[patient] = {}
        for position in positions:
            patient_data[patient][position] = {'Kumar': {}, 'MFA': {}}

            data_kumar = sp.io.loadmat(f"{path}\\{patient}\\{patient}_HG_{position}_sigChannel_goodTrials.mat")
            data_mfa = sp.io.loadmat(f"{path}\\{patient}\\{patient}_HG_{position}_sigChannel_goodTrials_MFA.mat")

            patient_data[patient][position]['Kumar'] = {
                'hg_trace': data_kumar['hgTrace'],
                'hg_map': data_kumar['hgMap'],
                'phon_seq': data_kumar['phonSeqLabels']
            }

            patient_data[patient][position]['MFA'] = {
                'hg_trace': data_mfa['hgTrace'],
                'hg_map': data_mfa['hgMap'],
                'phon_seq': data_mfa['phonSeqLabels']
            }

    # Save to pickle
    with open(pkl_path, "wb") as f:
        pickle.dump(patient_data, f)

    print("Processed and saved patient_data to pickle.")
# dictionary structure is patient_data[patient][position][method][hg_trace, hg_map, phon_seq]
# you can access the data as follows: patient_data['S14']['p1']['Kumar']['hg_trace'] etc.
# Out:
# Loaded patient_data from pickle.

# %% [markdown]
# # Decoding

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.decomposition import PCA
from sklearn.svm import SVC, LinearSVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import balanced_accuracy_score, accuracy_score, confusion_matrix
from tqdm.notebook import tqdm
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Extension for Scikit-learn* enabled (https://github.com/uxlfoundation/scikit-learn-intelex)

# %%
class PCA_noCenter(BaseEstimator, TransformerMixin):

    def __init__(self, n_components=None):
        self.n_components = n_components

    def fit(self, X, y=None):
        U, S, Vt = np.linalg.svd(X, full_matrices=False)
        k = self._get_components(X, S)
        self.components_ = Vt[:k].T
        self.explained_variance_ = S**2
        return self

    def transform(self, X):
        return X @ self.components_

    def fit_transform(self, X, y=None):
        self.fit(X, y)
        return self.transform(X)
    
    def _get_components(self, X, S):
        if self.n_components is None or self.n_components >= min(X.shape):
            print("n_components is None or greater than the number of features/samples. Using n_components = min(X.shape)")
            return min(X.shape)
        elif self.n_components < 1:
            cum_var = np.cumsum(S**2) / np.sum(S**2)
            return np.argmax(cum_var >= self.n_components) + 1
        else:
            return int(self.n_components)

# %%
var_expl = np.arange(0.1, 1, 0.1)  
n_folds = 20  
do_cv = True 

# main cv - defines train/test splits
cv = StratifiedKFold(n_splits=n_folds, shuffle=True)

# combine PCA and decoder into pipeline for ease of use with grid search
# clf = Pipeline([('pca', PCA_noCenter(n_components=0.8)), ('decoder', SVC(kernel='rbf', class_weight='balanced'))])
clf = Pipeline([('pca', PCA_noCenter(n_components=0.8)), ('classifier', LinearDiscriminantAnalysis())])

param_grid = {'pca__n_components': var_expl, 'decoder__C': np.logspace(-3, 3, 7), 'decoder__gamma': np.logspace(-3, 3, 7)}

# %%
def warn(*args, **kwargs):
    
    pass
import warnings
warnings.warn = warn

# %% [markdown]
# ## Decoder for each position separately for S14 Kumar and S14 MFA

# %%
def run_decoder(X, y, num_folds=20, do_cv=True, var_expl=[0.8], num_iter=5):
    cv = StratifiedKFold(n_splits=num_folds, shuffle=True)
    accs = []
    for _ in range(num_iter):
        y_true_all = []
        y_pred_all = []
        if do_cv:
            iter = cv.split(X, y)
        else:
            iter = cv.split(X, y)
        for train_idx, test_idx in iter:
        # for train_idx, test_idx in cv.split(X, y):
            # split data
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # print(X_train.shape)

            if do_cv:
                # nested cv - searches for best variance explained parameter by splitting training data over multiple folds
                grid = GridSearchCV(clf, {'pca__n_components': var_expl}, cv=num_folds, scoring='balanced_accuracy', n_jobs=-1)
                grid.fit(X_train, y_train)
                #print('Best variance explained:', grid.best_params_['pca__n_components'], 'Best score:', grid.best_score_)

                # grid search automatically refits the best model to the training data so we can just predict on the test data
                y_pred = grid.predict(X_test)
                
            else:
                clf.fit(X_train, y_train)
                y_pred = clf.predict(X_test)

            y_true_all.extend(y_test)
            y_pred_all.extend(y_pred)

        cmat = confusion_matrix(y_true_all, y_pred_all)
        acc_cmat = np.trace(cmat) / np.sum(cmat)
        # cmat_norm = cmat / np.sum(cmat, axis=1)[:, None]
        # acc_norm = np.trace(cmat_norm) / cmat_norm.shape[0]
        acc_bal = balanced_accuracy_score(y_true_all, y_pred_all)
        # cmat = cmat / np.sum(cmat, axis=1)[:, None]

        accs.append(acc_cmat)
        #print('Balanced accuracy:', round(acc_bal, 3), 'Confusion matrix accuracy:', round(acc_cmat, 3))

    return accs

# %% [markdown]
# ## 10 Iterations -- Every position -- Every patient -- Kumar and MFA

# %%
# run the decoder for each patient and position separately
patients = ['S14', 'S22', 'S23', 'S26', 'S33']
positions = ['p1', 'p2', 'p3']
methods = ['Kumar', 'MFA']
DWs = ["1S", "0.8S", "0.6S", "0.4S", "0.2S", "0.1S", "0.05S", 
       "0.025S", "0.015S", "0.01S"]

dwdict = {
    "1S": [-0.5, 0.5], 
    "0.8S": [-0.4, 0.4],
    "0.6S": [-0.3, 0.3],
    "0.4S": [-0.2, 0.2],
    "0.2S": [-0.1, 0.1],
    "0.1S": [-0.05, 0.05],
    "0.05S": [-0.025, 0.025], 
    "0.025S": [-0.015, 0.010],
    "0.015S": [-0.010, 0.005],
    "0.01S": [-0.005, 0.005]
    
}


accuraciesDWs = {dw: {method: {patient: {position: [] for position in positions} for patient in patients}
                      for method in methods} for dw in DWs}
def cutX(X, dw):
    timevec = np.linspace(-0.5, 0.5, 200) 
    dws, dwe =  dwdict[dw][0], dwdict[dw][1] 
    maski = (timevec >= dws) & (timevec <= dwe)
    X = X[:, :, maski]
    timevec = timevec[maski]
    return timevec, X
    

for patient_idx, patient in tqdm(enumerate(patients), desc='Patients', total=len(patients), colour='#b58f48'):
    numfoldds = 5 if patient == "S33" else 20
    for pos_idx, position in enumerate(positions):
        for method_idx, method in enumerate(methods):
            for dw in DWs:
                if dw in ["1S", "0.8S", "0.6S", "0.4S", "0.2S", "0.1S", "0.05S"]:
                    continue
                X = patient_data[patient][position][method]['hg_trace']
                X = X.transpose(0,2,1)
                print(f"This is X before cutting {X.shape}")
                print(f"This is dw: {dw}")
                timevec,X = cutX(X, dw)
                print(f"This is X after cutting {X.shape}")
                print(timevec) 
                X = X.reshape(X.shape[0], -1) # reshape to (n_trials, n_features)
                y = patient_data[patient][position][method]['phon_seq'][:,pos_idx]
                accuraciesDWs[dw][method][patient][position] = run_decoder(X, y, num_folds=numfoldds, do_cv=True, var_expl=[0.8], num_iter=10)
                print(f"Phoneme Decoding for {patient}, {position}, {method}, {dw} completed.")
                avacc = np.mean(accuraciesDWs[dw][method][patient][position])
                print(f"Average Accuracy for {patient}, {position}, {method}, {dw}: {avacc}")
# Out:
# Patients:   0%|          | 0/5 [00:00<?, ?it/s]
# This is X before cutting (144, 111, 200)
# This is dw: 0.025S
# This is X after cutting (144, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S14, p1, Kumar, 0.025S completed.
# Average Accuracy for S14, p1, Kumar, 0.025S: 0.33472222222222225
# This is X before cutting (144, 111, 200)
# This is dw: 0.015S
# This is X after cutting (144, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S14, p1, Kumar, 0.015S completed.
# Average Accuracy for S14, p1, Kumar, 0.015S: 0.3305555555555556
# This is X before cutting (144, 111, 200)
# This is dw: 0.01S
# This is X after cutting (144, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S14, p1, Kumar, 0.01S completed.
# Average Accuracy for S14, p1, Kumar, 0.01S: 0.3402777777777778
# This is X before cutting (148, 111, 200)
# This is dw: 0.025S
# This is X after cutting (148, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S14, p1, MFA, 0.025S completed.
# Average Accuracy for S14, p1, MFA, 0.025S: 0.2797297297297297
# This is X before cutting (148, 111, 200)
# This is dw: 0.015S
# This is X after cutting (148, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S14, p1, MFA, 0.015S completed.
# Average Accuracy for S14, p1, MFA, 0.015S: 0.27702702702702703
# This is X before cutting (148, 111, 200)
# This is dw: 0.01S
# This is X after cutting (148, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S14, p1, MFA, 0.01S completed.
# Average Accuracy for S14, p1, MFA, 0.01S: 0.27635135135135125
# This is X before cutting (144, 111, 200)
# This is dw: 0.025S
# This is X after cutting (144, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S14, p2, Kumar, 0.025S completed.
# Average Accuracy for S14, p2, Kumar, 0.025S: 0.19861111111111113
# This is X before cutting (144, 111, 200)
# This is dw: 0.015S
# This is X after cutting (144, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S14, p2, Kumar, 0.015S completed.
# Average Accuracy for S14, p2, Kumar, 0.015S: 0.2048611111111111
# This is X before cutting (144, 111, 200)
# This is dw: 0.01S
# This is X after cutting (144, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S14, p2, Kumar, 0.01S completed.
# Average Accuracy for S14, p2, Kumar, 0.01S: 0.2041666666666667
# This is X before cutting (148, 111, 200)
# This is dw: 0.025S
# This is X after cutting (148, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S14, p2, MFA, 0.025S completed.
# Average Accuracy for S14, p2, MFA, 0.025S: 0.1445945945945946
# This is X before cutting (148, 111, 200)
# This is dw: 0.015S
# This is X after cutting (148, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S14, p2, MFA, 0.015S completed.
# Average Accuracy for S14, p2, MFA, 0.015S: 0.1472972972972973
# This is X before cutting (148, 111, 200)
# This is dw: 0.01S
# This is X after cutting (148, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S14, p2, MFA, 0.01S completed.
# Average Accuracy for S14, p2, MFA, 0.01S: 0.13783783783783785
# This is X before cutting (144, 111, 200)
# This is dw: 0.025S
# This is X after cutting (144, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S14, p3, Kumar, 0.025S completed.
# Average Accuracy for S14, p3, Kumar, 0.025S: 0.28541666666666665
# This is X before cutting (144, 111, 200)
# This is dw: 0.015S
# This is X after cutting (144, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S14, p3, Kumar, 0.015S completed.
# Average Accuracy for S14, p3, Kumar, 0.015S: 0.2798611111111111
# This is X before cutting (144, 111, 200)
# This is dw: 0.01S
# This is X after cutting (144, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S14, p3, Kumar, 0.01S completed.
# Average Accuracy for S14, p3, Kumar, 0.01S: 0.29305555555555557
# This is X before cutting (148, 111, 200)
# This is dw: 0.025S
# This is X after cutting (148, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S14, p3, MFA, 0.025S completed.
# Average Accuracy for S14, p3, MFA, 0.025S: 0.18513513513513513
# This is X before cutting (148, 111, 200)
# This is dw: 0.015S
# This is X after cutting (148, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S14, p3, MFA, 0.015S completed.
# Average Accuracy for S14, p3, MFA, 0.015S: 0.19594594594594594
# This is X before cutting (148, 111, 200)
# This is dw: 0.01S
# This is X after cutting (148, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S14, p3, MFA, 0.01S completed.
# Average Accuracy for S14, p3, MFA, 0.01S: 0.19864864864864865
# This is X before cutting (151, 74, 200)
# This is dw: 0.025S
# This is X after cutting (151, 74, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S22, p1, Kumar, 0.025S completed.
# Average Accuracy for S22, p1, Kumar, 0.025S: 0.152317880794702
# This is X before cutting (151, 74, 200)
# This is dw: 0.015S
# This is X after cutting (151, 74, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S22, p1, Kumar, 0.015S completed.
# Average Accuracy for S22, p1, Kumar, 0.015S: 0.15695364238410597
# This is X before cutting (151, 74, 200)
# This is dw: 0.01S
# This is X after cutting (151, 74, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S22, p1, Kumar, 0.01S completed.
# Average Accuracy for S22, p1, Kumar, 0.01S: 0.147682119205298
# This is X before cutting (152, 74, 200)
# This is dw: 0.025S
# This is X after cutting (152, 74, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S22, p1, MFA, 0.025S completed.
# Average Accuracy for S22, p1, MFA, 0.025S: 0.20657894736842106
# This is X before cutting (152, 74, 200)
# This is dw: 0.015S
# This is X after cutting (152, 74, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S22, p1, MFA, 0.015S completed.
# Average Accuracy for S22, p1, MFA, 0.015S: 0.19736842105263158
# This is X before cutting (152, 74, 200)
# This is dw: 0.01S
# This is X after cutting (152, 74, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S22, p1, MFA, 0.01S completed.
# Average Accuracy for S22, p1, MFA, 0.01S: 0.20394736842105265
# This is X before cutting (151, 74, 200)
# This is dw: 0.025S
# This is X after cutting (151, 74, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S22, p2, Kumar, 0.025S completed.
# Average Accuracy for S22, p2, Kumar, 0.025S: 0.22185430463576158
# This is X before cutting (151, 74, 200)
# This is dw: 0.015S
# This is X after cutting (151, 74, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S22, p2, Kumar, 0.015S completed.
# Average Accuracy for S22, p2, Kumar, 0.015S: 0.2291390728476821
# This is X before cutting (151, 74, 200)
# This is dw: 0.01S
# This is X after cutting (151, 74, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S22, p2, Kumar, 0.01S completed.
# Average Accuracy for S22, p2, Kumar, 0.01S: 0.21258278145695364
# This is X before cutting (152, 74, 200)
# This is dw: 0.025S
# This is X after cutting (152, 74, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S22, p2, MFA, 0.025S completed.
# Average Accuracy for S22, p2, MFA, 0.025S: 0.2039473684210526
# This is X before cutting (152, 74, 200)
# This is dw: 0.015S
# This is X after cutting (152, 74, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S22, p2, MFA, 0.015S completed.
# Average Accuracy for S22, p2, MFA, 0.015S: 0.18618421052631579
# This is X before cutting (152, 74, 200)
# This is dw: 0.01S
# This is X after cutting (152, 74, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S22, p2, MFA, 0.01S completed.
# Average Accuracy for S22, p2, MFA, 0.01S: 0.19539473684210526
# This is X before cutting (151, 74, 200)
# This is dw: 0.025S
# This is X after cutting (151, 74, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S22, p3, Kumar, 0.025S completed.
# Average Accuracy for S22, p3, Kumar, 0.025S: 0.16953642384105957
# This is X before cutting (151, 74, 200)
# This is dw: 0.015S
# This is X after cutting (151, 74, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S22, p3, Kumar, 0.015S completed.
# Average Accuracy for S22, p3, Kumar, 0.015S: 0.1781456953642384
# This is X before cutting (151, 74, 200)
# This is dw: 0.01S
# This is X after cutting (151, 74, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S22, p3, Kumar, 0.01S completed.
# Average Accuracy for S22, p3, Kumar, 0.01S: 0.17152317880794704
# This is X before cutting (152, 74, 200)
# This is dw: 0.025S
# This is X after cutting (152, 74, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S22, p3, MFA, 0.025S completed.
# Average Accuracy for S22, p3, MFA, 0.025S: 0.12105263157894737
# This is X before cutting (152, 74, 200)
# This is dw: 0.015S
# This is X after cutting (152, 74, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S22, p3, MFA, 0.015S completed.
# Average Accuracy for S22, p3, MFA, 0.015S: 0.1236842105263158
# This is X before cutting (152, 74, 200)
# This is dw: 0.01S
# This is X after cutting (152, 74, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S22, p3, MFA, 0.01S completed.
# Average Accuracy for S22, p3, MFA, 0.01S: 0.12171052631578946
# This is X before cutting (151, 63, 200)
# This is dw: 0.025S
# This is X after cutting (151, 63, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S23, p1, Kumar, 0.025S completed.
# Average Accuracy for S23, p1, Kumar, 0.025S: 0.23178807947019867
# This is X before cutting (151, 63, 200)
# This is dw: 0.015S
# This is X after cutting (151, 63, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S23, p1, Kumar, 0.015S completed.
# Average Accuracy for S23, p1, Kumar, 0.015S: 0.23576158940397357
# This is X before cutting (151, 63, 200)
# This is dw: 0.01S
# This is X after cutting (151, 63, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S23, p1, Kumar, 0.01S completed.
# Average Accuracy for S23, p1, Kumar, 0.01S: 0.21655629139072846
# This is X before cutting (154, 63, 200)
# This is dw: 0.025S
# This is X after cutting (154, 63, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S23, p1, MFA, 0.025S completed.
# Average Accuracy for S23, p1, MFA, 0.025S: 0.1974025974025974
# This is X before cutting (154, 63, 200)
# This is dw: 0.015S
# This is X after cutting (154, 63, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S23, p1, MFA, 0.015S completed.
# Average Accuracy for S23, p1, MFA, 0.015S: 0.19480519480519481
# This is X before cutting (154, 63, 200)
# This is dw: 0.01S
# This is X after cutting (154, 63, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S23, p1, MFA, 0.01S completed.
# Average Accuracy for S23, p1, MFA, 0.01S: 0.1844155844155844
# This is X before cutting (151, 63, 200)
# This is dw: 0.025S
# This is X after cutting (151, 63, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S23, p2, Kumar, 0.025S completed.
# Average Accuracy for S23, p2, Kumar, 0.025S: 0.2
# This is X before cutting (151, 63, 200)
# This is dw: 0.015S
# This is X after cutting (151, 63, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S23, p2, Kumar, 0.015S completed.
# Average Accuracy for S23, p2, Kumar, 0.015S: 0.219205298013245
# This is X before cutting (151, 63, 200)
# This is dw: 0.01S
# This is X after cutting (151, 63, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S23, p2, Kumar, 0.01S completed.
# Average Accuracy for S23, p2, Kumar, 0.01S: 0.2178807947019868
# This is X before cutting (154, 63, 200)
# This is dw: 0.025S
# This is X after cutting (154, 63, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S23, p2, MFA, 0.025S completed.
# Average Accuracy for S23, p2, MFA, 0.025S: 0.20064935064935066
# This is X before cutting (154, 63, 200)
# This is dw: 0.015S
# This is X after cutting (154, 63, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S23, p2, MFA, 0.015S completed.
# Average Accuracy for S23, p2, MFA, 0.015S: 0.19545454545454546
# This is X before cutting (154, 63, 200)
# This is dw: 0.01S
# This is X after cutting (154, 63, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S23, p2, MFA, 0.01S completed.
# Average Accuracy for S23, p2, MFA, 0.01S: 0.19610389610389609
# This is X before cutting (151, 63, 200)
# This is dw: 0.025S
# This is X after cutting (151, 63, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S23, p3, Kumar, 0.025S completed.
# Average Accuracy for S23, p3, Kumar, 0.025S: 0.10198675496688743
# This is X before cutting (151, 63, 200)
# This is dw: 0.015S
# This is X after cutting (151, 63, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S23, p3, Kumar, 0.015S completed.
# Average Accuracy for S23, p3, Kumar, 0.015S: 0.09602649006622517
# This is X before cutting (151, 63, 200)
# This is dw: 0.01S
# This is X after cutting (151, 63, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S23, p3, Kumar, 0.01S completed.
# Average Accuracy for S23, p3, Kumar, 0.01S: 0.09867549668874173
# This is X before cutting (154, 63, 200)
# This is dw: 0.025S
# This is X after cutting (154, 63, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S23, p3, MFA, 0.025S completed.
# Average Accuracy for S23, p3, MFA, 0.025S: 0.14285714285714285
# This is X before cutting (154, 63, 200)
# This is dw: 0.015S
# This is X after cutting (154, 63, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S23, p3, MFA, 0.015S completed.
# Average Accuracy for S23, p3, MFA, 0.015S: 0.1396103896103896
# This is X before cutting (154, 63, 200)
# This is dw: 0.01S
# This is X after cutting (154, 63, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S23, p3, MFA, 0.01S completed.
# Average Accuracy for S23, p3, MFA, 0.01S: 0.14090909090909093
# This is X before cutting (148, 111, 200)
# This is dw: 0.025S
# This is X after cutting (148, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S26, p1, Kumar, 0.025S completed.
# Average Accuracy for S26, p1, Kumar, 0.025S: 0.32770270270270274
# This is X before cutting (148, 111, 200)
# This is dw: 0.015S
# This is X after cutting (148, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S26, p1, Kumar, 0.015S completed.
# Average Accuracy for S26, p1, Kumar, 0.015S: 0.32499999999999996
# This is X before cutting (148, 111, 200)
# This is dw: 0.01S
# This is X after cutting (148, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S26, p1, Kumar, 0.01S completed.
# Average Accuracy for S26, p1, Kumar, 0.01S: 0.3310810810810811
# This is X before cutting (149, 111, 200)
# This is dw: 0.025S
# This is X after cutting (149, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S26, p1, MFA, 0.025S completed.
# Average Accuracy for S26, p1, MFA, 0.025S: 0.3651006711409396
# This is X before cutting (149, 111, 200)
# This is dw: 0.015S
# This is X after cutting (149, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S26, p1, MFA, 0.015S completed.
# Average Accuracy for S26, p1, MFA, 0.015S: 0.3718120805369127
# This is X before cutting (149, 111, 200)
# This is dw: 0.01S
# This is X after cutting (149, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S26, p1, MFA, 0.01S completed.
# Average Accuracy for S26, p1, MFA, 0.01S: 0.36644295302013424
# This is X before cutting (148, 111, 200)
# This is dw: 0.025S
# This is X after cutting (148, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S26, p2, Kumar, 0.025S completed.
# Average Accuracy for S26, p2, Kumar, 0.025S: 0.31891891891891894
# This is X before cutting (148, 111, 200)
# This is dw: 0.015S
# This is X after cutting (148, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S26, p2, Kumar, 0.015S completed.
# Average Accuracy for S26, p2, Kumar, 0.015S: 0.31756756756756754
# This is X before cutting (148, 111, 200)
# This is dw: 0.01S
# This is X after cutting (148, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S26, p2, Kumar, 0.01S completed.
# Average Accuracy for S26, p2, Kumar, 0.01S: 0.3087837837837838
# This is X before cutting (149, 111, 200)
# This is dw: 0.025S
# This is X after cutting (149, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S26, p2, MFA, 0.025S completed.
# Average Accuracy for S26, p2, MFA, 0.025S: 0.34630872483221475
# This is X before cutting (149, 111, 200)
# This is dw: 0.015S
# This is X after cutting (149, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S26, p2, MFA, 0.015S completed.
# Average Accuracy for S26, p2, MFA, 0.015S: 0.34697986577181206
# This is X before cutting (149, 111, 200)
# This is dw: 0.01S
# This is X after cutting (149, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S26, p2, MFA, 0.01S completed.
# Average Accuracy for S26, p2, MFA, 0.01S: 0.3389261744966443
# This is X before cutting (148, 111, 200)
# This is dw: 0.025S
# This is X after cutting (148, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S26, p3, Kumar, 0.025S completed.
# Average Accuracy for S26, p3, Kumar, 0.025S: 0.2891891891891892
# This is X before cutting (148, 111, 200)
# This is dw: 0.015S
# This is X after cutting (148, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S26, p3, Kumar, 0.015S completed.
# Average Accuracy for S26, p3, Kumar, 0.015S: 0.2722972972972973
# This is X before cutting (148, 111, 200)
# This is dw: 0.01S
# This is X after cutting (148, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S26, p3, Kumar, 0.01S completed.
# Average Accuracy for S26, p3, Kumar, 0.01S: 0.28648648648648656
# This is X before cutting (149, 111, 200)
# This is dw: 0.025S
# This is X after cutting (149, 111, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S26, p3, MFA, 0.025S completed.
# Average Accuracy for S26, p3, MFA, 0.025S: 0.24899328859060404
# This is X before cutting (149, 111, 200)
# This is dw: 0.015S
# This is X after cutting (149, 111, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S26, p3, MFA, 0.015S completed.
# Average Accuracy for S26, p3, MFA, 0.015S: 0.2402684563758389
# This is X before cutting (149, 111, 200)
# This is dw: 0.01S
# This is X after cutting (149, 111, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S26, p3, MFA, 0.01S completed.
# Average Accuracy for S26, p3, MFA, 0.01S: 0.2523489932885906
# This is X before cutting (46, 149, 200)
# This is dw: 0.025S
# This is X after cutting (46, 149, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S33, p1, Kumar, 0.025S completed.
# Average Accuracy for S33, p1, Kumar, 0.025S: 0.3456521739130435
# This is X before cutting (46, 149, 200)
# This is dw: 0.015S
# This is X after cutting (46, 149, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S33, p1, Kumar, 0.015S completed.
# Average Accuracy for S33, p1, Kumar, 0.015S: 0.3347826086956522
# This is X before cutting (46, 149, 200)
# This is dw: 0.01S
# This is X after cutting (46, 149, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S33, p1, Kumar, 0.01S completed.
# Average Accuracy for S33, p1, Kumar, 0.01S: 0.3586956521739131
# This is X before cutting (46, 149, 200)
# This is dw: 0.025S
# This is X after cutting (46, 149, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S33, p1, MFA, 0.025S completed.
# Average Accuracy for S33, p1, MFA, 0.025S: 0.32826086956521744
# This is X before cutting (46, 149, 200)
# This is dw: 0.015S
# This is X after cutting (46, 149, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S33, p1, MFA, 0.015S completed.
# Average Accuracy for S33, p1, MFA, 0.015S: 0.3130434782608696
# This is X before cutting (46, 149, 200)
# This is dw: 0.01S
# This is X after cutting (46, 149, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S33, p1, MFA, 0.01S completed.
# Average Accuracy for S33, p1, MFA, 0.01S: 0.36086956521739133
# This is X before cutting (46, 149, 200)
# This is dw: 0.025S
# This is X after cutting (46, 149, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S33, p2, Kumar, 0.025S completed.
# Average Accuracy for S33, p2, Kumar, 0.025S: 0.21956521739130436
# This is X before cutting (46, 149, 200)
# This is dw: 0.015S
# This is X after cutting (46, 149, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S33, p2, Kumar, 0.015S completed.
# Average Accuracy for S33, p2, Kumar, 0.015S: 0.22391304347826088
# This is X before cutting (46, 149, 200)
# This is dw: 0.01S
# This is X after cutting (46, 149, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S33, p2, Kumar, 0.01S completed.
# Average Accuracy for S33, p2, Kumar, 0.01S: 0.22826086956521738
# This is X before cutting (46, 149, 200)
# This is dw: 0.025S
# This is X after cutting (46, 149, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S33, p2, MFA, 0.025S completed.
# Average Accuracy for S33, p2, MFA, 0.025S: 0.2260869565217391
# This is X before cutting (46, 149, 200)
# This is dw: 0.015S
# This is X after cutting (46, 149, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S33, p2, MFA, 0.015S completed.
# Average Accuracy for S33, p2, MFA, 0.015S: 0.25434782608695655
# This is X before cutting (46, 149, 200)
# This is dw: 0.01S
# This is X after cutting (46, 149, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S33, p2, MFA, 0.01S completed.
# Average Accuracy for S33, p2, MFA, 0.01S: 0.23043478260869565
# This is X before cutting (46, 149, 200)
# This is dw: 0.025S
# This is X after cutting (46, 149, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S33, p3, Kumar, 0.025S completed.
# Average Accuracy for S33, p3, Kumar, 0.025S: 0.2608695652173913
# This is X before cutting (46, 149, 200)
# This is dw: 0.015S
# This is X after cutting (46, 149, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S33, p3, Kumar, 0.015S completed.
# Average Accuracy for S33, p3, Kumar, 0.015S: 0.28478260869565214
# This is X before cutting (46, 149, 200)
# This is dw: 0.01S
# This is X after cutting (46, 149, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S33, p3, Kumar, 0.01S completed.
# Average Accuracy for S33, p3, Kumar, 0.01S: 0.2782608695652174
# This is X before cutting (46, 149, 200)
# This is dw: 0.025S
# This is X after cutting (46, 149, 5)
# [-0.01256281 -0.00753769 -0.00251256  0.00251256  0.00753769]
# Phoneme Decoding for S33, p3, MFA, 0.025S completed.
# Average Accuracy for S33, p3, MFA, 0.025S: 0.17608695652173914
# This is X before cutting (46, 149, 200)
# This is dw: 0.015S
# This is X after cutting (46, 149, 3)
# [-0.00753769 -0.00251256  0.00251256]
# Phoneme Decoding for S33, p3, MFA, 0.015S completed.
# Average Accuracy for S33, p3, MFA, 0.015S: 0.1782608695652174
# This is X before cutting (46, 149, 200)
# This is dw: 0.01S
# This is X after cutting (46, 149, 2)
# [-0.00251256  0.00251256]
# Phoneme Decoding for S33, p3, MFA, 0.01S completed.
# Average Accuracy for S33, p3, MFA, 0.01S: 0.17391304347826086

# %%
# get dictionary full structure 

print(accuraciesDWs.items())
# Out:
# dict_items([('1S', {'Kumar': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}, 'MFA': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}}), ('0.8S', {'Kumar': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}, 'MFA': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}}), ('0.6S', {'Kumar': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}, 'MFA': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}}), ('0.4S', {'Kumar': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}, 'MFA': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}}), ('0.2S', {'Kumar': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}, 'MFA': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}}), ('0.1S', {'Kumar': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}, 'MFA': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}}), ('0.05S', {'Kumar': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}, 'MFA': {'S14': {'p1': [], 'p2': [], 'p3': []}, 'S22': {'p1': [], 'p2': [], 'p3': []}, 'S23': {'p1': [], 'p2': [], 'p3': []}, 'S26': {'p1': [], 'p2': [], 'p3': []}, 'S33': {'p1': [], 'p2': [], 'p3': []}}}), ('0.025S', {'Kumar': {'S14': {'p1': [0.3333333333333333, 0.3402777777777778, 0.3333333333333333, 0.3402777777777778, 0.3333333333333333, 0.3333333333333333, 0.3333333333333333, 0.3263888888888889, 0.3472222222222222, 0.3263888888888889], 'p2': [0.2152777777777778, 0.19444444444444445, 0.1875, 0.20833333333333334, 0.1875, 0.1875, 0.2152777777777778, 0.1875, 0.19444444444444445, 0.20833333333333334], 'p3': [0.2847222222222222, 0.2569444444444444, 0.2708333333333333, 0.2986111111111111, 0.2708333333333333, 0.2986111111111111, 0.2986111111111111, 0.2847222222222222, 0.2777777777777778, 0.3125]}, 'S22': {'p1': [0.1456953642384106, 0.1390728476821192, 0.1390728476821192, 0.16556291390728478, 0.13245033112582782, 0.1456953642384106, 0.17880794701986755, 0.17880794701986755, 0.152317880794702, 0.1456953642384106], 'p2': [0.1986754966887417, 0.24503311258278146, 0.2052980132450331, 0.24503311258278146, 0.2119205298013245, 0.2185430463576159, 0.23178807947019867, 0.2185430463576159, 0.23178807947019867, 0.2119205298013245], 'p3': ...

# %%
data = []
for patient in patients:
    for position in positions:
        for method in methods:
            for dw in DWs:
                data.extend([(patient, position, method, dw, acc) for acc in accuraciesDWs[dw][method][patient][position]])

Accuracy_DWs = pd.DataFrame(data, columns=['Patient', 'Position', 'Method', 'Decoding TW', 'Accuracy'])
# print head
print(Accuracy_DWs.head())
# Out:
#   Patient Position Method Decoding TW  Accuracy
# 0     S14       p1  Kumar      0.025S  0.333333
# 1     S14       p1  Kumar      0.025S  0.340278
# 2     S14       p1  Kumar      0.025S  0.333333
# 3     S14       p1  Kumar      0.025S  0.340278
# 4     S14       p1  Kumar      0.025S  0.333333

# %%
# save it to a csv file
Accuracy_DWs.to_csv('Accuracy_DWs3.csv', index=False) # :) this is the 3rd time we add more DWs

# %%
# load kumar mfa dataframe
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import sklearn 
import os
from matplotlib import cm as colours 
from colorama import Fore, Back, Style
from scipy.stats import sem
import joblib

Accuracy_df_Kumar_MFA = pd.read_csv(r"C:\Users\Nabiya\Box\Academic-Duke\CoganLab\Summer 2024\intraop\ieeg_data_intraop\Accuracy_df_Kumar_MFA.csv")
print(Accuracy_df_Kumar_MFA.head(20))
# print shape of the dataframe
print(Accuracy_df_Kumar_MFA.shape)

# %% [markdown]
# ## Bar Plots to show difference between Kumar and MFA

# %%
from scipy.stats import ttest_rel, ttest_ind

# %%
# rename method column to Annotator

# %%
# before plotting, run statistical tests, ttest_rel



kumar_array = Accuracy_df_Kumar_MFA[Accuracy_df_Kumar_MFA['Method'] == 'Kumar']['Accuracy']
mfa_array = Accuracy_df_Kumar_MFA[Accuracy_df_Kumar_MFA['Method'] == 'MFA']['Accuracy']

result = ttest_rel(kumar_array, mfa_array)
print(result)


# plot the accuracies as a barplot. for now, let's not separate by patient nor position. just hueing by method

fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(data=Accuracy_df_Kumar_MFA, hue='Method', y='Accuracy', ax=ax)
sns.stripplot(data=Accuracy_df_Kumar_MFA, hue='Method', y='Accuracy', ax=ax, dodge=True, legend=False, palette='dark')
ax.set_title('HG Power Decoding Accuracy for Kumar and MFA', fontsize=20, fontweight='bold', fontname='Arial')
ax.set_xlabel('Method', fontsize=15)
ax.set_ylabel('Accuracy', fontsize=15)
# put the pvalue up there
ax.text(1.1, 1.1, f"Paired t-test pvalue={result.pvalue}", fontsize=15, ha='center', va='center', transform=ax.transAxes,
        color='blue', bbox=dict(facecolor='yellow', alpha=0.5, edgecolor='black', boxstyle='round,pad=1'))

plt.show()

# %% [markdown]
# ## Distribution: All Patients, by positions, Kumar vs. MFA

# %%
from statsmodels.stats.anova import AnovaRM

model = AnovaRM(Accuracy_df_Kumar_MFA, depvar='Accuracy', subject='Patient', within=['Position', 'Method'], 
                aggregate_func=np.mean)
result = model.fit().anova_table
print(result)


## Barplot: All Patients, by positions, Kumar vs. MFA

fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(data=Accuracy_df_Kumar_MFA, hue='Method', y='Accuracy', x='Position')
sns.stripplot(data=Accuracy_df_Kumar_MFA, hue='Method', y='Accuracy', ax=ax, dodge=True, legend=False, palette='dark', x='Position')
ax.set_title('Decoding Accuracy for Kumar and MFA - By Position', fontsize=20, fontweight='bold', fontname='Arial')
ax.set_xlabel('Position', fontsize=15)
ax.set_ylabel('Accuracy', fontsize=15)
# put the pvalue up there
ax.text(1.1, 1.1, f"Paired t-test pvalue={result.loc['Method', 'Pr > F']:.3g}", fontsize=15, ha='center', va='center', transform=ax.transAxes,
        color='blue', bbox=dict(facecolor='yellow', alpha=0.5, edgecolor='black', boxstyle='round,pad=1'))

plt.show()

# %% [markdown]
# ## Distribution: All positions, by Patients, Kumar vs. MFA

# %%
## Distribution: All positions, by Patients, Kumar vs. MFA

import statsmodels.api as sm
import statsmodels.formula.api as smf

formula = 'Accuracy ~ Method'
model = smf.mixedlm(formula, Accuracy_df_Kumar_MFA, groups=Accuracy_df_Kumar_MFA['Patient'])
result = model.fit()
print(result.summary())

# plotting now 

sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,8))
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(data=Accuracy_df_Kumar_MFA, hue='Method', y='Accuracy', x='Patient')
sns.stripplot(data=Accuracy_df_Kumar_MFA, hue='Method', y='Accuracy', ax=ax, dodge=True, legend=False, palette='dark', x='Patient')
ax.set_title('Decoding Accuracy for Kumar and MFA - By Patient', fontsize=20, fontweight='bold', fontname='Arial')
ax.set_xlabel('Position', fontsize=15)
ax.set_ylabel('Accuracy', fontsize=15)
# put the pvalue up there
ax.text(1.1, 1.1, f"Paired t-test pvalue={result.loc['Method', 'Pr > F']:.3g}", fontsize=15, ha='center', va='center', transform=ax.transAxes,
        color='blue', bbox=dict(facecolor='yellow', alpha=0.5, edgecolor='black', boxstyle='round,pad=1'))

plt.show()
